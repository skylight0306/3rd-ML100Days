# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %% [markdown]
#    我認為機器學習如果可以配合深度學習領域使得機器在各個應用中學習更多分辨技能取代人力，好比說email信箱往往會有很多廣告的郵件 ，我們可以透過深度學習去訓練機器讓機器代替我們去分類那些屬於重要的信件。深度學習領域包含的範圍又十分廣泛，可以透過深度學習 讓機器學習如何駕駛一輛車，避免撞到障礙物或是其他車等等，透過影像的辨識分析出他們分別是甚麼，並且透過影像顏色掃描得知紅燈綠 燈這些路況。深度學習之所以會逐漸越來越紅不是沒有原因的，人類的大腦計算和反應速度遠遠不及電腦，電腦可以計算並且評估預測接下 來的走向，像是AlphaGo就是一個很好的例子，透過深度學習的方式去學習棋譜，並且配合電腦計算能力強的優勢預測整局棋盤的走向。 當今機器學習的深度學習領域正在世界各地討論、研究如何將深度學習結合不同的領域而擦出不一樣的火花。 我認為醫療方面可以結合深度學習的運用，若能在醫療設備都加裝深度學習的機器，就可以從病患身體的狀況去正確的判斷身體發生那些問 題，機器從眾多的數據分析當中可以精確分辨出病人的狀況，未來也不用只透過醫生的經驗去判斷，機器內儲存數十年數百年所有病患的病 史和身體狀況，相較於數十年的醫生看診經驗，我認為還是機器的判斷會略勝一籌。若是能將機器學習結合醫療這塊不僅僅能準確地了解病 人的狀況，有時候更能在關鍵時候透過正確且快速的判斷救病人一命。
